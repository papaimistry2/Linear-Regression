# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data = pd.read_csv("data_for_lr.csv")
data.head()
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
data.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
#Drop the missing values
data = data.dropna()

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(data.x,data.y)

# %%
new_data = data.drop('y',axis = 'columns')
new_data
# Out:
#         x
# 0    24.0
# 1    50.0
# 2    15.0
# 3    38.0
# 4    87.0
# ..    ...
# 695  58.0
# 696  93.0
# 697  82.0
# 698  66.0
# 699  97.0
#
# [699 rows x 1 columns]

# %%
model = linear_model.LinearRegression()
X_train = np.array(new_data)
Y_train = np.array(data.y)
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.predict([[88]])
# Out:
# array([87.95049614])
